# %% [markdown]
# ### Exemplo I - Importando o Pandas

# %%
import pandas as pd
print(pd.__version__)
pd.options.display.float_format = '{:.3f}'.format
# Out:
# 1.3.4

# %% [markdown]
# ### Exemplo II - Criando um dataset de exemplo (dados fictícios) usando Pandas

# %%
dados={'Estado':["SP","RJ","ES","MG","PR", "RS", "SC"],
      'Populacao':[46649132,17463349,4108508,21411923,11597484,11466630,7338473]}
basepop=pd.DataFrame(dados)
basepop
# Out:
#   Estado  Populacao
# 0     SP   46649132
# 1     RJ   17463349
# 2     ES    4108508
# 3     MG   21411923
# 4     PR   11597484
# 5     RS   11466630
# 6     SC    7338473

# %%
#Verificando o tipo do objeto criado
type(basepop)
# Out:
# pandas.core.frame.DataFrame

# %%
### Observando as primeiras n linhas da tabela
basepop.head(3)
# Out:
#   Estado  Populacao
# 0     SP   46649132
# 1     RJ   17463349
# 2     ES    4108508

# %%
### Observando as últimas n linhas da tabela
basepop.tail(3)
# Out:
#   Estado  Populacao
# 4     PR   11597484
# 5     RS   11466630
# 6     SC    7338473

# %%
#Trazendo a quantidade de linhas e colunas do dataframe
basepop.shape
# Out:
# (7, 2)

# %% [markdown]
# ### Exemplo III - Criando uma série de dados

# %%
#Gerando a série
serie=[1,2,4,8,16,32]
minha_serie=pd.Series(serie)
minha_serie
# Out:
# 0     1
# 1     2
# 2     4
# 3     8
# 4    16
# 5    32
# dtype: int64

# %%
#Colocando um rótulo nos valores dos índices da série
minha_serie=pd.Series(serie,index=["a","b","c","d","e","f"])
minha_serie
# Out:
# a     1
# b     2
# c     4
# d     8
# e    16
# f    32
# dtype: int64

# %%
#Criando uma série simples a partir de um dicionário
calorias = {"dia1": 450, "dia2": 398, "dia3": 367}
minhas_calorias = pd.Series(calorias)
print(minhas_calorias)
# Out:
# dia1    450
# dia2    398
# dia3    367
# dtype: int64

# %% [markdown]
# ### Exemplo IV - Filtrando dados em um dataframe

# %%
#Fitrando uma coluna específica
basepop["Estado"]
# Out:
# 0    SP
# 1    RJ
# 2    ES
# 3    MG
# 4    PR
# 5    RS
# 6    SC
# Name: Estado, dtype: object

# %%
#Filtrando uma linha específica
basepop.loc[[0]]
# Out:
#   Estado  Populacao
# 0     SP   46649132

# %%
#Filtrando mais de uma linha
basepop.loc[[1,4]]
# Out:
#   Estado  Populacao
# 1     RJ   17463349
# 4     PR   11597484

# %%
#Filtrando mais de uma linha de forma sequencial
basepop.loc[1:3]
# Out:
#   Estado  Populacao
# 1     RJ   17463349
# 2     ES    4108508
# 3     MG   21411923

# %%
#Filtrando mais de uma linha de forma sequencial e de uma coluna específica
basepop.loc[1:3, "Estado"]
# Out:
# 1    RJ
# 2    ES
# 3    MG
# Name: Estado, dtype: object

# %%
#Filtrando mais de uma linha de forma sequencial
basepop.iloc[0:3,0:2]
# Out:
#   Estado  Populacao
# 0     SP   46649132
# 1     RJ   17463349
# 2     ES    4108508

# %%
#Filtrando todas as colunas de uma linha olu conjunto de linhas
basepop.iloc[0:3,:]
# Out:
#   Estado  Populacao
# 0     SP   46649132
# 1     RJ   17463349
# 2     ES    4108508

# %%
#Filtrando todas as linhas de uma coluna ou grupo de colunas
basepop.iloc[:, 0:1]
# Out:
#   Estado
# 0     SP
# 1     RJ
# 2     ES
# 3     MG
# 4     PR
# 5     RS
# 6     SC

# %%
#Filtrando linhas a partir de uma condição específica
basepop.loc[basepop["Populacao"]>10000000]
# Out:
#   Estado  Populacao
# 0     SP   46649132
# 1     RJ   17463349
# 3     MG   21411923
# 4     PR   11597484
# 5     RS   11466630

# %%
#Filtrando linhas a partir de mais de uma condição específica, em que ambas sejam atendidas(AND)
basepop.loc[(basepop["Populacao"]>10000000) & (basepop["Estado"]=="SP")]
# Out:
#   Estado  Populacao
# 0     SP   46649132

# %%
#Filtrando linhas a partir de mais de uma condição específica, em que pelo menos uma seja atendida(OR)
basepop.loc[(basepop["Populacao"]>10000000) | (basepop["Estado"]=="SP")]
# Out:
#   Estado  Populacao
# 0     SP   46649132
# 1     RJ   17463349
# 3     MG   21411923
# 4     PR   11597484
# 5     RS   11466630

# %%
#Usando o comando query para filtrar de uma maneira ainda mais simples
basepop.query("Populacao<10000000 & Estado=='ES'")
# Out:
#   Estado  Populacao
# 2     ES    4108508

# %%
#Usando o comando filter para selecão de linhas e colunas
basepop.filter(["Estado"])
# Out:
#   Estado
# 0     SP
# 1     RJ
# 2     ES
# 3     MG
# 4     PR
# 5     RS
# 6     SC

# %%
#Extraindo a média de população dos estados
mediapop=basepop["Populacao"].mean()
mediapop
# Out:
# 17147928.42857143

# %%
#Filtrando estados com população acima da média
basepop.query("Populacao > @ mediapop")
# Out:
#   Estado  Populacao
# 0     SP   46649132
# 1     RJ   17463349
# 3     MG   21411923

# %%
#Filtrando um conjunto de estados específico
basepop[basepop["Estado"].isin(["SP", "RS", "PR"])]
# Out:
#   Estado  Populacao
# 0     SP   46649132
# 4     PR   11597484
# 5     RS   11466630

# %% [markdown]
# ### Exemplo V - Importando dados de tabelas externas

# %%
#Importando uma tabela Excel para análise (formato .xlsx)
indsocdem=pd.read_excel("Indicadores Socio-Demograficos.xlsx", sheet_name="BASE_DADOS")
indsocdem.head(10)
# Out:
#                 CIDADE ESTADO  IBGE_RES_POP  IBGE_POP_URB  POP_ABAIXO_1  \
# 0      Abadia De Goiás     GO        6876.0        5300.0          69.0
# 1  Abadia Dos Dourados     MG        6704.0        4154.0          38.0
# 2            Abadiânia     GO       15757.0       10656.0         139.0
# 3               Abaeté     MG       22690.0       18464.0         176.0
# 4           Abaetetuba     PA      141100.0       82956.0        1354.0
# 5              Abaiara     CE       10496.0        4538.0          98.0
# 6               Abaíra     BA        8316.0        3725.0          37.0
# 7                Abaré     BA       17064.0        8994.0         167.0
# 8               Abatiá     PR        7764.0        5685.0          69.0
# 9        Abdon Batista     SC        2653.0         724.0          12.0
#
#    POP_1_4  POP_5_9  POP_10-14  POP_15-59  POP_60_MAIS  ...  IDHM_Educacao  \
# 0    318.0    438.0      517.0     3542.0        416.0  ...          0.622
# 1    207.0    260.0      351.0     2709.0        589.0  ...          0.563
# 2    650.0    894.0     1087.0     6896.0        990.0  ...          0.579
# 3    856.0   1233.0     1539.0    11979.0       2681.0  ...          0.556
# 4   5567.0   7618.0     8905.0    53516.0       5996.0  ...          0.537
# 5    323.0    421.0      483.0     2631.0        582.0  ...          0.612
# 6    156.0    263.0      277.0     2319.0        673.0  ...          0.510
# 7    733.0    978.0      927.0     5386.0        803.0  ...          0.460
# 8    302.0    370.0      483.0     3650.0        811.0  ...          0.596
# 9     32.0     49.0       63.0      479.0         89.0  ...          0.625
#
#         LONG        LAT  TV_CABO  POP_ESTIMADA         PIB  PIB_CAPITA  \
# 0 -49.440548 -16.758812    360.0        8583.0      166.41    20664.57
# 1 -47.396832 -18.487565     77.0        6972.0      180.09    25591.70
# 2 -48.718812 -16.182672    227.0       19614.0   287984.49    15628.40
# 3 -45.446191 -19.155848   1230.0       23223.0   430235.36    18250.42
# 4 -48.884404  -1.723470   3389.0      156292.0  1249255.29     8222.36
# 5 -39.047547  -7.356977     29.0       11663.0    73151.46     6370.41
# 6 -41.661608 -13.253532    952.0        8767.0    64324.59     6982.70
# 7 -39.116588  -8.723418     51.0       19814.0   124754.26     6256.80
# 8 -50.312527 -23.300494     55.0        7507.0   165048.21    21173.60
# 9 -51.025272 -27.608987    109.0        2577.0    64742.01    24739.02
#
#    CARROS    MOTOS  TOT_EMPRESAS
# 0  2158.0   1246.0         284.0
# 1  2227.0   1142.0         476.0
# 2  2838.0   1426.0         288.0
# 3  6928.0   2953.0         621.0
# 4  5277.0  25661.0         931.0
# 5   553.0   1674.0          86.0
# 6   896.0    696.0         191.0
# 7   613.0   1532.0          87.0
# 8  2168.0    912.0         285.0
# 9   976.0    345.0          69.0
#
# [10 rows x 23 columns]

# %%
#Importando um arquivo texto no formato .csv (arquivos texto separados por vírgulas)
telco=pd.read_csv("Telco Customer Churn.csv", sep = ',')
telco.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
#Importando um arquivo no formato .txt
people=pd.read_csv("PeopleAnalytics.txt", sep="\t", usecols=["Attrition", "Age", "StockOptionLevel"])
people.head()
# Out:
#   Attrition  Age  StockOptionLevel
# 0       Yes   41                 0
# 1        No   49                 1
# 2       Yes   37                 0
# 3        No   33                 0
# 4        No   27                 1

# %% [markdown]
# ### Exemplo VI - Descrição básica dos dados

# %%
#Análise descritiva básica do dataframe sobre Indicadores Sócio-Demográficos
indsocdem.describe().round(3)
# Out:
#        IBGE_POP_URB  POP_ABAIXO_1    POP_1_4    POP_5_9  POP_10-14  \
# count      5565.000      5565.000   5565.000   5565.000   5565.000
# mean      27594.658       383.276   1544.531   2069.321   2381.423
# std      185957.864      2326.809   9253.090  12313.518  14186.075
# min         174.000         0.000      5.000      7.000     12.000
# 25%        2801.000        38.000    158.000    220.000    259.000
# 50%        6170.000        92.000    376.000    516.000    588.000
# 75%       15302.000       232.000    951.000   1300.000   1478.000
# max    10463636.000    129464.000 514794.000 684443.000 783702.000
#
#         POP_15-59  POP_60_MAIS     IDHM  IDHM_Renda  IDHM_Longevidade  \
# count    5565.000     5565.000 5565.000    5565.000          5565.000
# mean    18211.869     3004.239    0.659       0.643             0.802
# std    125205.947    23247.843    0.072       0.081             0.045
# min        94.000       29.000    0.418       0.400             0.672
# 25%      1734.000      341.000    0.599       0.572             0.769
# 50%      3841.000      722.000    0.665       0.654             0.808
# 75%      9628.000     1724.000    0.718       0.707             0.836
# max   7058221.000  1293012.000    0.862       0.891             0.894
#
#        IDHM_Educacao     LONG      LAT     TV_CABO  POP_ESTIMADA  \
# count       5565.000 5564.000 5564.000    5570.000      5570.000
# mean           0.559  -46.226  -16.444    3094.209     37431.759
# std            0.093    6.410    8.281   35794.788    219969.003
# min            0.207  -72.917  -33.688       1.000       786.000
# 25%            0.490  -50.867  -22.838      88.000      5454.000
# 50%            0.560  -46.516  -18.089     247.000     11590.500
# 75%            0.631  -41.405   -8.489     815.000     25295.500
# max            0.825  -32.435    4.585 2047668.000  12176866.000
#
#                 PIB  PIB_CAPITA      CARROS       MOTOS  TOT_EMPRESAS
# count      5570.000    5570.000    5562.000    5562.000      5570.000
# mean     954583.631   21126.181    9859.429    4878.615       906.753
# std    11219549.873   20332.651   91886.936   20943.915      8333.768
# min          14.960    3190.570       2.000       4.000         6.000
# 25%       43709.462    9057.610     602.000     591.000        68.000
# 50%      125153.425   15869.625    1438.500    1285.000       162.000
# 75%      329539.282   26154.722    4086.000    3294.500       448.000
# max   687035889.610  314637.690 5740995.000 1134570.000    530446.000
